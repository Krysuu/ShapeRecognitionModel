# %% [markdown]
# # Etap 1

# %% [markdown]
# Celem notatnika jest przegląd kilku dostępnych architektur konwolucyjnych sieci neuronowych i przetestowanie ich zastosowania do rozpoznawania elementów konstrukcyjnych. Sprawdzano również zastosowanie transferu wiedzy z modeli wytrenowanych na zbiorze danych ImageNet. Zbiór ten składa się z milionów obrazów ręcznie zaklasyfikowanych do co najmniej 20 tysięcy klas.
#
# Wybrane architektury:
# - ResNet50 - rozmiar wejściowy 224x224
# - Xception - rozmiar wejściowy 299x299
# - VGG16 - rozmiar wejściowy 224x224
#
# Biblioteka Keras udostępnia modele dla każdej wyżej wymienionej architektury oraz gotowe wagi z możliwością ich zamrożenia podczas treningu na własnych danych.
#
# #### Zbiór danych wykorzystany w testach
# Na podstawie dostarczonych plików .stl wygenerowano 1520 obrazów o rozdzielczości 300x300 pikseli. Dla każdego pliku .stl wygenerowano 4 obrazy pod różnym kątem.
# Ograniczono się do czterech klas elementów:
# - ceownik - 308 plików
# - dwuteownik - 324 plików
# - katownik - 92 plików
# - plaskownik - 796 plików
#
# Całą pulę podzielono na zbiór treningowy i testowy w stosunku 80:20 dla każdej klasy.
#
# #### Przebieg testów
# Dla każdej architektury wytrenowano model trzykrotnie:
# - Model zainicjowany wytrenowanymi wagi z zablokowaną możliwością edycji
# - Model zainicjowany wytrenowanymi wagi z możliwością edycji
# - Model zainicjowany losowymi wagami
#
# Do gotowych modeli dodano dwie warstwy zwracające prawdopodobieństwo przynależności do każdej z klas. Każdy model uruchomiono z wykorzystaniem identycznych hiperparametrów. W celu porównania skuteczności wygenerowano macierze pomyłek oraz obliczono miary trafności.

# %% [markdown]
# # Import zależności

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.models import Model
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau, TensorBoard
from keras import optimizers, losses, activations, models
from keras.layers import Convolution2D, Dense, Input, Flatten, Dropout, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D, Concatenate
from tensorflow.keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

import tensorflow.keras.applications.resnet50 as resnet50
import tensorflow.keras.applications.xception as xception
import tensorflow.keras.applications.vgg16 as vgg16
ROWS=300
COLS=300

# %% [markdown]
# # Definicje funckcji

# %%
def preprocess_and_load_data(preprocessing_function, batch_size = 16):
    resnet50_idg = ImageDataGenerator(preprocessing_function=preprocessing_function)

    train_gen = resnet50_idg.flow_from_directory(
        'STL_IMAGES/train',
        target_size=(ROWS, COLS),
        batch_size = batch_size
    )

    test_gen = resnet50_idg.flow_from_directory(
        'STL_IMAGES/test',
        target_size=(ROWS, COLS),
        batch_size = batch_size,
        shuffle = False,
        class_mode='binary'
    )
    return train_gen, test_gen

def prepare_model(pretrained_model):
    nclass = len(train_gen.class_indices)
    resnet_model = Sequential()
    resnet_model.add(pretrained_model)
    resnet_model.add(Flatten())
    resnet_model.add(Dense(128, activation='relu'))
    resnet_model.add(Dense(nclass, activation='softmax'))

    model = resnet_model
    model.compile(loss='categorical_crossentropy', 
                  optimizer=SGD(),
                  metrics=['accuracy'])
    model.summary()
    return model

def fit_model(model, weights_path):
    checkpoint = ModelCheckpoint(weights_path, monitor='accuracy', verbose=1, save_best_only=True, mode='max')
    early = EarlyStopping(monitor="accuracy", mode="max", patience=10)
    callbacks_list = [checkpoint, early]
    history = model.fit(train_gen, 
                        epochs=10,
                        shuffle=True, 
                        verbose=2,
                        callbacks=callbacks_list)
    return history

def show_history_plot(history):
    sns.set(font_scale = 1)
    fig1 = plt.gcf()
    plt.plot(history.history['accuracy'])
    plt.grid()
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epochs')
    plt.legend(['accuracy'])
    plt.show()
    
def predict(model, test_gen, weights_path):
    model.load_weights(weights_path)
    predicts = model.predict(test_gen, verbose = True, workers = 2)
    return predicts

def show_confusion_matrix(train_gen, test_gen, predicts):
    sns.set(font_scale = 2)
    label_names = list(train_gen.class_indices)
    y_true = test_gen.labels
    y_pred = np.argmax(predicts, axis=1)

    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize = (15, 15))

    ax= plt.subplot()
    sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', ax=ax)

    ax.set_xlabel('Predicted labels')
    ax.set_ylabel('True labels')
    ax.set_title('Confusion Matrix')
    ax.xaxis.set_ticklabels(label_names)
    ax.yaxis.set_ticklabels(label_names)

    print("Accaccuracy score: ", accuracy_score(y_true, y_pred)*100)
    
def show_misclassified():
    predicts_top1 = np.argmax(predicts, axis=1)
    label_index = {v: k for k,v in train_gen.class_indices.items()}
    predicts_top1 = [label_index[p] for p in predicts_top1]

    df = pd.DataFrame(columns=['fname', 'true_label', 'predicted_label'])
    df['fname'] = [os.path.basename(x) for x in test_gen.filenames]
    df['true_label'] = [label_index[p] for p in test_gen.labels]
    df['predicted_label'] = predicts_top1

    return df.iloc[np.where((df['true_label'] != df['predicted_label']))]

# %% [markdown]
# # Prównanie istniejących rozwiązań
# ## ResNet50 - transfer wiedzy - zamrożone wagi

# %%
train_gen, test_gen = preprocess_and_load_data(resnet50.preprocess_input)
# Out:
# Found 1218 images belonging to 4 classes.
# Found 302 images belonging to 4 classes.

# %%
pretrained_model = resnet50.ResNet50(weights='imagenet', include_top=False, input_shape=(ROWS, COLS,3))
pretrained_model.trainable = False
model = prepare_model(pretrained_model)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 10, 10, 2048)      23587712
#
#  flatten (Flatten)           (None, 204800)            0
#
#  dense (Dense)               (None, 128)               26214528
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 49,802,756
# Trainable params: 26,215,044
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
weights_path = "resnet50_weights_with_freeze.best.hdf5"
history = fit_model(model, weights_path)
# Out:
# Epoch 1/10
#
# Epoch 1: accuracy improved from -inf to 0.52299, saving model to resnet50_weights_with_freeze.best.hdf5
# 77/77 - 11s - loss: 19.6120 - accuracy: 0.5230 - 11s/epoch - 142ms/step
# Epoch 2/10
#
# Epoch 2: accuracy improved from 0.52299 to 0.56076, saving model to resnet50_weights_with_freeze.best.hdf5
# 77/77 - 6s - loss: 1.2499 - accuracy: 0.5608 - 6s/epoch - 78ms/step
# Epoch 3/10
#
# Epoch 3: accuracy improved from 0.56076 to 0.58867, saving model to resnet50_weights_with_freeze.best.hdf5
# 77/77 - 6s - loss: 1.1874 - accuracy: 0.5887 - 6s/epoch - 77ms/step
# Epoch 4/10
#
# Epoch 4: accuracy improved from 0.58867 to 0.60673, saving model to resnet50_weights_with_freeze.best.hdf5
# 77/77 - 6s - loss: 1.1135 - accuracy: 0.6067 - 6s/epoch - 76ms/step
# Epoch 5/10
#
# Epoch 5: accuracy improved from 0.60673 to 0.60837, saving model to resnet50_weights_with_freeze.best.hdf5
# 77/77 - 6s - loss: 1.0851 - accuracy: 0.6084 - 6s/epoch - 78ms/step
# Epoch 6/10
#
# Epoch 6: accuracy improved from 0.60837 to 0.62151, saving model to resnet50_weights_with_freeze.best.hdf5
# 77/77 - 6s - loss: 1.0429 - accuracy: 0.6215 - 6s/epoch - 80ms/step
# Epoch 7/10
#
# Epoch 7: accuracy improved from 0.62151 to 0.63054, saving model to resnet50_weights_with_freeze.best.hdf5
# 77/77 - 6s - loss: 0.9090 - accuracy: 0.6305 - 6s/epoch - 80ms/step
# Epoch 8/10
#
# Epoch 8: accuracy improved from 0.63054 to 0.63629, saving model to resnet50_weights_with_freeze.best.hdf5
# 77/77 - 6s - loss: 0.8470 - accuracy: 0.6363 - 6s/epoch - 78ms/step
# Epoch 9/10
#
# Epoch 9: accuracy did not improve from 0.63629
# 77/77 - 6s - loss: 0.7844 - accuracy: 0.6256 - 6s/epoch - 73ms/step
# Epoch 10/10
#
# Epoch 10: accuracy did not improve from 0.63629
# 77/77 - 6s - loss: 0.7601 - accuracy: 0.6322 - 6s/epoch - 74ms/step

# %%
show_history_plot(history)

# %%
predicts = predict(model, test_gen, weights_path)
show_confusion_matrix(train_gen, test_gen, predicts)
# Out:
# 19/19 [==============================] - 3s 118ms/step
# Accaccuracy score:  63.90728476821192

# %%
show_misclassified()
# Out:
#                          fname true_label predicted_label
# 0     ceownik_00001-view01.png    ceownik      plaskownik
# 1     ceownik_00001-view03.png    ceownik      plaskownik
# 2     ceownik_00002-view02.png    ceownik      plaskownik
# 3     ceownik_00003-view02.png    ceownik      plaskownik
# 4     ceownik_00006-view02.png    ceownik      plaskownik
# ..                         ...        ...             ...
# 138  katownik_00020-view02.png   katownik      plaskownik
# 139  katownik_00022-view03.png   katownik      plaskownik
# 140  katownik_00023-view02.png   katownik      plaskownik
# 141  katownik_00023-view03.png   katownik      plaskownik
# 142  katownik_00023-view04.png   katownik      plaskownik
#
# [109 rows x 3 columns]

# %% [markdown]
# ## ResNet50 - transfer wiedzy - bez zamrożenia

# %%
train_gen, test_gen = preprocess_and_load_data(resnet50.preprocess_input)

pretrained_model = resnet50.ResNet50(weights='imagenet', include_top=False, input_shape=(ROWS, COLS,3))
pretrained_model.trainable = True
model = prepare_model(pretrained_model)

weights_path = "resnet50_weights_without_freeze.best.hdf5"
history = fit_model(model, weights_path)
# Out:
# Found 1218 images belonging to 4 classes.
# Found 302 images belonging to 4 classes.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 10, 10, 2048)      23587712
#
#  flatten_1 (Flatten)         (None, 204800)            0
#
#  dense_2 (Dense)             (None, 128)               26214528
#
#  dense_3 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 49,802,756
# Trainable params: 49,749,636
# Non-trainable params: 53,120
# _________________________________________________________________
# Epoch 1/10
#
# Epoch 1: accuracy improved from -inf to 0.50657, saving model to resnet50_weights_without_freeze.best.hdf5
# 77/77 - 24s - loss: 4.4422 - accuracy: 0.5066 - 24s/epoch - 309ms/step
# Epoch 2/10
#
# Epoch 2: accuracy improved from 0.50657 to 0.62726, saving model to resnet50_weights_without_freeze.best.hdf5
# 77/77 - 19s - loss: 0.9480 - accuracy: 0.6273 - 19s/epoch - 248ms/step
# Epoch 3/10
#
# Epoch 3: accuracy improved from 0.62726 to 0.67241, saving model to resnet50_weights_without_freeze.best.hdf5
# 77/77 - 19s - loss: 0.8050 - accuracy: 0.6724 - 19s/epoch - 243ms/step
# Epoch 4/10
#
# Epoch 4: accuracy improved from 0.67241 to 0.72578, saving model to resnet50_weights_without_freeze.best.hdf5
# 77/77 - 19s - loss: 0.6673 - accuracy: 0.7258 - 19s/epoch - 249ms/step
# Epoch 5/10
#
# Epoch 5: accuracy improved from 0.72578 to 0.77176, saving model to resnet50_weights_without_freeze.best.hdf5
# 77/77 - 19s - loss: 0.5771 - accuracy: 0.7718 - 19s/epoch - 245ms/step
# Epoch 6/10
#
# Epoch 6: accuracy improved from 0.77176 to 0.79146, saving model to resnet50_weights_without_freeze.best.hdf5
# 77/77 - 19s - loss: 0.5661 - accuracy: 0.7915 - 19s/epoch - 248ms/step
# Epoch 7/10
#
# Epoch 7: accuracy improved from 0.79146 to 0.80788, saving model to resnet50_weights_without_freeze.best.hdf5
# 77/77 - 19s - loss: 0.5400 - accuracy: 0.8079 - 19s/epoch - 241ms/step
# Epoch 8/10
#
# Epoch 8: accuracy improved from 0.80788 to 0.82512, saving model to resnet50_weights_without_freeze.best.hdf5
# 77/77 - 19s - loss: 0.4584 - accuracy: 0.8251 - 19s/epoch - 242ms/step
# Epoch 9/10
#
# Epoch 9: accuracy improved from 0.82512 to 0.86700, saving model to resnet50_weights_without_freeze.best.hdf5
# 77/77 - 19s - loss: 0.3425 - accuracy: 0.8670 - 19s/epoch - 243ms/step
# Epoch 10/10
#
# Epoch 10: accuracy did not improve from 0.86700
# 77/77 - 18s - loss: 0.3901 - accuracy: 0.8555 - 18s/epoch - 236ms/step

# %%
show_history_plot(history)

# %%
predicts = predict(model, test_gen, weights_path)
show_confusion_matrix(train_gen, test_gen, predicts)
# Out:
# 19/19 [==============================] - 2s 76ms/step
# Accaccuracy score:  82.11920529801324

# %%
show_misclassified()
# Out:
#                            fname  true_label predicted_label
# 0       ceownik_00001-view01.png     ceownik      plaskownik
# 2       ceownik_00002-view02.png     ceownik      plaskownik
# 3       ceownik_00003-view02.png     ceownik      plaskownik
# 4       ceownik_00006-view02.png     ceownik      plaskownik
# 7       ceownik_00013-view01.png     ceownik      plaskownik
# 8       ceownik_00014-view04.png     ceownik      plaskownik
# 12      ceownik_00017-view04.png     ceownik      plaskownik
# 13      ceownik_00018-view02.png     ceownik      plaskownik
# 14      ceownik_00022-view01.png     ceownik      plaskownik
# 29      ceownik_00039-view04.png     ceownik      plaskownik
# 31      ceownik_00041-view01.png     ceownik      plaskownik
# 41      ceownik_00052-view02.png     ceownik      plaskownik
# 42      ceownik_00055-view01.png     ceownik      plaskownik
# 46      ceownik_00063-view03.png     ceownik      dwuteownik
# 52      ceownik_00068-view03.png     ceownik      plaskownik
# 57      ceownik_00071-view01.png     ceownik      plaskownik
# 58      ceownik_00072-view02.png     ceownik      plaskownik
# 59      ceownik_00074-view01.png     ceownik      plaskownik
# 60      ceownik_00076-view01.png     ceownik      plaskownik
# 61   dwuteownik_00001-view03.png  dwuteownik      plaskownik
# 67   dwuteownik_00007-view01.png  dwuteownik      plaskownik
# 68   dwuteownik_00009-view01.png  dwuteownik      plaskownik
# 69   dwuteownik_00012-view02.png  dwuteownik      plaskownik
# 70   dwuteownik_00012-view04.png  dwuteownik      plaskownik
# 75   dwuteownik_00019-view02.png  dwuteownik      plaskownik
# 76   dwuteownik_00020-view01.png  dwuteownik      plaskownik
# 78   dwuteownik_00023-view01.png  dwuteownik      plaskownik
# 79   dwuteownik_00024-view02.png  dwuteownik      plaskownik
# 81   dwuteownik_00027-view04.png  dwuteownik      plaskownik
# 91   dwuteownik_00040-view03.png  dwuteownik      plaskownik
# 92   dwuteownik_00042-view03.png  dwuteownik      plaskownik
# 93   dwuteownik_00043-view02.png  dwuteownik      plaskownik
# 96   dwuteownik_00046-view01.png  dwuteownik      plaskownik
# 105  dwuteownik_00059-view04.png  dwuteownik      plaskownik
# 106  dwuteownik_00061-view04.png  dwuteownik         ceownik
# 107  dwuteownik_00064-view01.png  dwuteownik      plaskownik
# 109  dwuteownik_00065-view01.png  dwuteownik      plaskownik
# 110  dwuteownik_00065-view02.png  dwuteownik      plaskownik
# 111  dwuteownik_00069-view02.png  dwuteownik         ceownik
# 112  dwuteownik_00069-view03.png  dwuteownik      plaskownik
# 114  dwuteownik_00071-view03.png  dwuteownik      plaskownik
# 115  dwuteownik_00071-view04.png  dwuteownik      plaskownik
# 116  dwuteownik_00073-view03.png  dwuteownik      plaskownik
# 121  dwuteownik_00081-view03.png  dwuteownik      plaskownik
# 122  dwuteownik_00082-view04.png  dwuteownik      plaskownik
# 123  dwuteownik_00084-view03.png  dwuteownik      plaskownik
# 130    katownik_00012-view03.png    katownik      plaskownik
# 132    katownik_00014-view04.png    katownik      plaskownik
# 133    katownik_00015-view03.png    katownik      plaskownik
# 134    katownik_00016-view01.png    katownik      plaskownik
# 136    katownik_00019-view03.png    katownik      plaskownik
# 140    katownik_00023-view02.png    katownik      dwuteownik
# 141    katownik_00023-view03.png    katownik      plaskownik
# 142    katownik_00023-view04.png    katownik      plaskownik

# %% [markdown]
# ## ResNet50 - bez transferu wiedzy

# %%
train_gen, test_gen = preprocess_and_load_data(resnet50.preprocess_input)

pretrained_model = resnet50.ResNet50(weights=None, include_top=False, input_shape=(ROWS, COLS,3))
pretrained_model.trainable = True
model = prepare_model(pretrained_model)

weights_path = "resnet50_weights.best.hdf5"
history = fit_model(model, weights_path)
# Out:
# Found 1218 images belonging to 4 classes.
# Found 302 images belonging to 4 classes.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 10, 10, 2048)      23587712
#
#  flatten_2 (Flatten)         (None, 204800)            0
#
#  dense_4 (Dense)             (None, 128)               26214528
#
#  dense_5 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 49,802,756
# Trainable params: 49,749,636
# Non-trainable params: 53,120
# _________________________________________________________________
# Epoch 1/10
#
# Epoch 1: accuracy improved from -inf to 0.50082, saving model to resnet50_weights.best.hdf5
# 77/77 - 21s - loss: 16.1950 - accuracy: 0.5008 - 21s/epoch - 279ms/step
# Epoch 2/10
#
# Epoch 2: accuracy improved from 0.50082 to 0.52299, saving model to resnet50_weights.best.hdf5
# 77/77 - 19s - loss: 1.2926 - accuracy: 0.5230 - 19s/epoch - 244ms/step
# Epoch 3/10
#
# Epoch 3: accuracy did not improve from 0.52299
# 77/77 - 18s - loss: 1.2520 - accuracy: 0.5230 - 18s/epoch - 237ms/step
# Epoch 4/10
#
# Epoch 4: accuracy did not improve from 0.52299
# 77/77 - 19s - loss: 1.2251 - accuracy: 0.5230 - 19s/epoch - 244ms/step
# Epoch 5/10
#
# Epoch 5: accuracy did not improve from 0.52299
# 77/77 - 20s - loss: 1.2078 - accuracy: 0.5230 - 20s/epoch - 254ms/step
# Epoch 6/10
#
# Epoch 6: accuracy did not improve from 0.52299
# 77/77 - 20s - loss: 1.1962 - accuracy: 0.5230 - 20s/epoch - 257ms/step
# Epoch 7/10
#
# Epoch 7: accuracy did not improve from 0.52299
# 77/77 - 20s - loss: 1.1885 - accuracy: 0.5230 - 20s/epoch - 257ms/step
# Epoch 8/10
#
# Epoch 8: accuracy did not improve from 0.52299
# 77/77 - 20s - loss: 1.1831 - accuracy: 0.5230 - 20s/epoch - 254ms/step
# Epoch 9/10
#
# Epoch 9: accuracy did not improve from 0.52299
# 77/77 - 19s - loss: 1.1794 - accuracy: 0.5230 - 19s/epoch - 249ms/step
# Epoch 10/10
#
# Epoch 10: accuracy did not improve from 0.52299
# 77/77 - 19s - loss: 1.1763 - accuracy: 0.5230 - 19s/epoch - 246ms/step

# %%
show_history_plot(history)

# %%
predicts = predict(model, test_gen, weights_path)
show_confusion_matrix(train_gen, test_gen, predicts)
# Out:
# 19/19 [==============================] - 2s 77ms/step
# Accaccuracy score:  52.64900662251656

# %%
show_misclassified()
# Out:
#                          fname true_label predicted_label
# 0     ceownik_00001-view01.png    ceownik      plaskownik
# 1     ceownik_00001-view03.png    ceownik      plaskownik
# 2     ceownik_00002-view02.png    ceownik      plaskownik
# 3     ceownik_00003-view02.png    ceownik      plaskownik
# 4     ceownik_00006-view02.png    ceownik      plaskownik
# ..                         ...        ...             ...
# 138  katownik_00020-view02.png   katownik      plaskownik
# 139  katownik_00022-view03.png   katownik      plaskownik
# 140  katownik_00023-view02.png   katownik      plaskownik
# 141  katownik_00023-view03.png   katownik      plaskownik
# 142  katownik_00023-view04.png   katownik      plaskownik
#
# [143 rows x 3 columns]

# %% [markdown]
# ## Xception - transfer wiedzy - zamrożone wagi

# %%
train_gen, test_gen = preprocess_and_load_data(xception.preprocess_input)

pretrained_model = xception.Xception(weights="imagenet", include_top=False, input_shape=(ROWS, COLS,3))
pretrained_model.trainable = False
model = prepare_model(pretrained_model)

weights_path = "xception_weights_with_freeze.best.hdf5"
history = fit_model(model, weights_path)
# Out:
# Found 1218 images belonging to 4 classes.
# Found 302 images belonging to 4 classes.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 10, 10, 2048)      20861480
#
#  flatten_3 (Flatten)         (None, 204800)            0
#
#  dense_6 (Dense)             (None, 128)               26214528
#
#  dense_7 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 47,076,524
# Trainable params: 26,215,044
# Non-trainable params: 20,861,480
# _________________________________________________________________
# Epoch 1/10
#
# Epoch 1: accuracy improved from -inf to 0.68473, saving model to xception_weights_with_freeze.best.hdf5
# 77/77 - 10s - loss: 1.1416 - accuracy: 0.6847 - 10s/epoch - 126ms/step
# Epoch 2/10
#
# Epoch 2: accuracy improved from 0.68473 to 0.84647, saving model to xception_weights_with_freeze.best.hdf5
# 77/77 - 7s - loss: 0.4166 - accuracy: 0.8465 - 7s/epoch - 96ms/step
# Epoch 3/10
#
# Epoch 3: accuracy improved from 0.84647 to 0.87028, saving model to xception_weights_with_freeze.best.hdf5
# 77/77 - 7s - loss: 0.3457 - accuracy: 0.8703 - 7s/epoch - 95ms/step
# Epoch 4/10
#
# Epoch 4: accuracy improved from 0.87028 to 0.91297, saving model to xception_weights_with_freeze.best.hdf5
# 77/77 - 7s - loss: 0.2475 - accuracy: 0.9130 - 7s/epoch - 96ms/step
# Epoch 5/10
#
# Epoch 5: accuracy improved from 0.91297 to 0.92365, saving model to xception_weights_with_freeze.best.hdf5
# 77/77 - 7s - loss: 0.1987 - accuracy: 0.9236 - 7s/epoch - 96ms/step
# Epoch 6/10
#
# Epoch 6: accuracy improved from 0.92365 to 0.93842, saving model to xception_weights_with_freeze.best.hdf5
# 77/77 - 7s - loss: 0.1681 - accuracy: 0.9384 - 7s/epoch - 96ms/step
# Epoch 7/10
#
# Epoch 7: accuracy improved from 0.93842 to 0.94581, saving model to xception_weights_with_freeze.best.hdf5
# 77/77 - 7s - loss: 0.1759 - accuracy: 0.9458 - 7s/epoch - 95ms/step
# Epoch 8/10
#
# Epoch 8: accuracy improved from 0.94581 to 0.96059, saving model to xception_weights_with_freeze.best.hdf5
# 77/77 - 8s - loss: 0.1173 - accuracy: 0.9606 - 8s/epoch - 98ms/step
# Epoch 9/10
#
# Epoch 9: accuracy did not improve from 0.96059
# 77/77 - 7s - loss: 0.1318 - accuracy: 0.9598 - 7s/epoch - 92ms/step
# Epoch 10/10
#
# Epoch 10: accuracy improved from 0.96059 to 0.97373, saving model to xception_weights_with_freeze.best.hdf5
# 77/77 - 7s - loss: 0.0902 - accuracy: 0.9737 - 7s/epoch - 96ms/step

# %%
show_history_plot(history)

# %%
predicts = predict(model, test_gen, weights_path)
show_confusion_matrix(train_gen, test_gen, predicts)
# Out:
# 19/19 [==============================] - 3s 136ms/step
# Accaccuracy score:  91.3907284768212

# %%
show_misclassified()
# Out:
#                            fname  true_label predicted_label
# 0       ceownik_00001-view01.png     ceownik        katownik
# 2       ceownik_00002-view02.png     ceownik      plaskownik
# 3       ceownik_00003-view02.png     ceownik      plaskownik
# 12      ceownik_00017-view04.png     ceownik      dwuteownik
# 42      ceownik_00055-view01.png     ceownik      plaskownik
# 52      ceownik_00068-view03.png     ceownik      plaskownik
# 58      ceownik_00072-view02.png     ceownik      dwuteownik
# 60      ceownik_00076-view01.png     ceownik        katownik
# 77   dwuteownik_00022-view02.png  dwuteownik         ceownik
# 79   dwuteownik_00024-view02.png  dwuteownik      plaskownik
# 81   dwuteownik_00027-view04.png  dwuteownik      plaskownik
# 92   dwuteownik_00042-view03.png  dwuteownik      plaskownik
# 111  dwuteownik_00069-view02.png  dwuteownik         ceownik
# 112  dwuteownik_00069-view03.png  dwuteownik         ceownik
# 122  dwuteownik_00082-view04.png  dwuteownik      plaskownik
# 126    katownik_00005-view01.png    katownik      plaskownik
# 130    katownik_00012-view03.png    katownik      plaskownik
# 133    katownik_00015-view03.png    katownik      plaskownik
# 136    katownik_00019-view03.png    katownik      plaskownik
# 138    katownik_00020-view02.png    katownik      plaskownik
# 140    katownik_00023-view02.png    katownik         ceownik
# 141    katownik_00023-view03.png    katownik      plaskownik
# 142    katownik_00023-view04.png    katownik      plaskownik
# 206  plaskownik_00081-view03.png  plaskownik      dwuteownik
# 207  plaskownik_00081-view04.png  plaskownik      dwuteownik
# 213  plaskownik_00089-view04.png  plaskownik         ceownik

# %% [markdown]
# ## Xception - transfer wiedzy - bez zamrożenia

# %%
train_gen, test_gen = preprocess_and_load_data(xception.preprocess_input)

pretrained_model = xception.Xception(weights="imagenet", include_top=False, input_shape=(ROWS, COLS,3))
pretrained_model.trainable = True
model = prepare_model(pretrained_model)

weights_path = "xception_weights_without_freeze.best.hdf5"
history = fit_model(model, weights_path)
# Out:
# Found 1218 images belonging to 4 classes.
# Found 302 images belonging to 4 classes.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 10, 10, 2048)      20861480
#
#  flatten_4 (Flatten)         (None, 204800)            0
#
#  dense_8 (Dense)             (None, 128)               26214528
#
#  dense_9 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 47,076,524
# Trainable params: 47,021,996
# Non-trainable params: 54,528
# _________________________________________________________________
# Epoch 1/10
#
# Epoch 1: accuracy improved from -inf to 0.51396, saving model to xception_weights_without_freeze.best.hdf5
# 77/77 - 42s - loss: 1.6345 - accuracy: 0.5140 - 42s/epoch - 547ms/step
# Epoch 2/10
#
# Epoch 2: accuracy improved from 0.51396 to 0.52299, saving model to xception_weights_without_freeze.best.hdf5
# 77/77 - 39s - loss: 1.2539 - accuracy: 0.5230 - 39s/epoch - 508ms/step
# Epoch 3/10
#
# Epoch 3: accuracy did not improve from 0.52299
# 77/77 - 38s - loss: 1.2096 - accuracy: 0.5230 - 38s/epoch - 488ms/step
# Epoch 4/10
#
# Epoch 4: accuracy did not improve from 0.52299
# 77/77 - 38s - loss: 1.1882 - accuracy: 0.5230 - 38s/epoch - 495ms/step
# Epoch 5/10
#
# Epoch 5: accuracy did not improve from 0.52299
# 77/77 - 38s - loss: 1.1777 - accuracy: 0.5230 - 38s/epoch - 494ms/step
# Epoch 6/10
#
# Epoch 6: accuracy did not improve from 0.52299
# 77/77 - 37s - loss: 1.1724 - accuracy: 0.5230 - 37s/epoch - 486ms/step
# Epoch 7/10
#
# Epoch 7: accuracy did not improve from 0.52299
# 77/77 - 37s - loss: 1.1692 - accuracy: 0.5230 - 37s/epoch - 486ms/step
# Epoch 8/10
#
# Epoch 8: accuracy did not improve from 0.52299
# 77/77 - 37s - loss: 1.1672 - accuracy: 0.5230 - 37s/epoch - 482ms/step
# Epoch 9/10
#
# Epoch 9: accuracy did not improve from 0.52299
# 77/77 - 38s - loss: 1.1658 - accuracy: 0.5230 - 38s/epoch - 490ms/step
# Epoch 10/10
#
# Epoch 10: accuracy did not improve from 0.52299
# 77/77 - 38s - loss: 1.1645 - accuracy: 0.5230 - 38s/epoch - 489ms/step

# %%
show_history_plot(history)

# %%
predicts = predict(model, test_gen, weights_path)
show_confusion_matrix(train_gen, test_gen, predicts)
# Out:
# 19/19 [==============================] - 2s 99ms/step
# Accaccuracy score:  52.64900662251656

# %%
show_misclassified()
# Out:
#                          fname true_label predicted_label
# 0     ceownik_00001-view01.png    ceownik      plaskownik
# 1     ceownik_00001-view03.png    ceownik      plaskownik
# 2     ceownik_00002-view02.png    ceownik      plaskownik
# 3     ceownik_00003-view02.png    ceownik      plaskownik
# 4     ceownik_00006-view02.png    ceownik      plaskownik
# ..                         ...        ...             ...
# 138  katownik_00020-view02.png   katownik      plaskownik
# 139  katownik_00022-view03.png   katownik      plaskownik
# 140  katownik_00023-view02.png   katownik      plaskownik
# 141  katownik_00023-view03.png   katownik      plaskownik
# 142  katownik_00023-view04.png   katownik      plaskownik
#
# [143 rows x 3 columns]

# %% [markdown]
# ## Xception - bez transferu wiedzy

# %%
train_gen, test_gen = preprocess_and_load_data(xception.preprocess_input)

pretrained_model = xception.Xception(weights=None, include_top=False, input_shape=(ROWS, COLS,3))
pretrained_model.trainable = True
model = prepare_model(pretrained_model)

weights_path = "xception_weights.best.hdf5"
history = fit_model(model, weights_path)
# Out:
# Found 1218 images belonging to 4 classes.
# Found 302 images belonging to 4 classes.
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 10, 10, 2048)      20861480
#
#  flatten_5 (Flatten)         (None, 204800)            0
#
#  dense_10 (Dense)            (None, 128)               26214528
#
#  dense_11 (Dense)            (None, 4)                 516
#
# =================================================================
# Total params: 47,076,524
# Trainable params: 47,021,996
# Non-trainable params: 54,528
# _________________________________________________________________
# Epoch 1/10
#
# Epoch 1: accuracy improved from -inf to 0.56568, saving model to xception_weights.best.hdf5
# 77/77 - 40s - loss: 1.1865 - accuracy: 0.5657 - 40s/epoch - 521ms/step
# Epoch 2/10
#
# Epoch 2: accuracy improved from 0.56568 to 0.72167, saving model to xception_weights.best.hdf5
# 77/77 - 38s - loss: 0.7552 - accuracy: 0.7217 - 38s/epoch - 487ms/step
# Epoch 3/10
#
# Epoch 3: accuracy improved from 0.72167 to 0.83415, saving model to xception_weights.best.hdf5
# 77/77 - 37s - loss: 0.4612 - accuracy: 0.8342 - 37s/epoch - 477ms/step
# Epoch 4/10
#
# Epoch 4: accuracy improved from 0.83415 to 0.89819, saving model to xception_weights.best.hdf5
# 77/77 - 37s - loss: 0.2928 - accuracy: 0.8982 - 37s/epoch - 476ms/step
# Epoch 5/10
#
# Epoch 5: accuracy improved from 0.89819 to 0.91872, saving model to xception_weights.best.hdf5
# 77/77 - 37s - loss: 0.2433 - accuracy: 0.9187 - 37s/epoch - 485ms/step
# Epoch 6/10
#
# Epoch 6: accuracy did not improve from 0.91872
# 77/77 - 39s - loss: 0.2628 - accuracy: 0.9171 - 39s/epoch - 512ms/step
# Epoch 7/10
#
# Epoch 7: accuracy did not improve from 0.91872
# 77/77 - 37s - loss: 0.3000 - accuracy: 0.9015 - 37s/epoch - 479ms/step
# Epoch 8/10
#
# Epoch 8: accuracy improved from 0.91872 to 0.97619, saving model to xception_weights.best.hdf5
# 77/77 - 37s - loss: 0.0788 - accuracy: 0.9762 - 37s/epoch - 480ms/step
# Epoch 9/10
#
# Epoch 9: accuracy improved from 0.97619 to 0.98851, saving model to xception_weights.best.hdf5
# 77/77 - 37s - loss: 0.0355 - accuracy: 0.9885 - 37s/epoch - 477ms/step
# Epoch 10/10
#
# Epoch 10: accuracy improved from 0.98851 to 0.99507, saving model to xception_weights.best.hdf5
# 77/77 - 37s - loss: 0.0220 - accuracy: 0.9951 - 37s/epoch - 476ms/step

# %%
show_history_plot(history)

# %%
predicts = predict(model, test_gen, weights_path)
show_confusion_matrix(train_gen, test_gen, predicts)
# Out:
# 19/19 [==============================] - 2s 95ms/step
# Accaccuracy score:  88.41059602649007

# %%
show_misclassified()
# Out:
#                            fname  true_label predicted_label
# 0       ceownik_00001-view01.png     ceownik      plaskownik
# 3       ceownik_00003-view02.png     ceownik      plaskownik
# 4       ceownik_00006-view02.png     ceownik      plaskownik
# 39      ceownik_00051-view01.png     ceownik      plaskownik
# 40      ceownik_00051-view02.png     ceownik      plaskownik
# 42      ceownik_00055-view01.png     ceownik      plaskownik
# 46      ceownik_00063-view03.png     ceownik      dwuteownik
# 53      ceownik_00069-view02.png     ceownik      plaskownik
# 54      ceownik_00069-view04.png     ceownik      plaskownik
# 55      ceownik_00070-view01.png     ceownik      plaskownik
# 56      ceownik_00070-view03.png     ceownik      plaskownik
# 60      ceownik_00076-view01.png     ceownik      plaskownik
# 75   dwuteownik_00019-view02.png  dwuteownik      plaskownik
# 76   dwuteownik_00020-view01.png  dwuteownik         ceownik
# 78   dwuteownik_00023-view01.png  dwuteownik      plaskownik
# 79   dwuteownik_00024-view02.png  dwuteownik      plaskownik
# 81   dwuteownik_00027-view04.png  dwuteownik      plaskownik
# 91   dwuteownik_00040-view03.png  dwuteownik      plaskownik
# 92   dwuteownik_00042-view03.png  dwuteownik      plaskownik
# 93   dwuteownik_00043-view02.png  dwuteownik      plaskownik
# 96   dwuteownik_00046-view01.png  dwuteownik      plaskownik
# 113  dwuteownik_00071-view01.png  dwuteownik      plaskownik
# 114  dwuteownik_00071-view03.png  dwuteownik      plaskownik
# 115  dwuteownik_00071-view04.png  dwuteownik      plaskownik
# 116  dwuteownik_00073-view03.png  dwuteownik      plaskownik
# 122  dwuteownik_00082-view04.png  dwuteownik      plaskownik
# 124  dwuteownik_00085-view02.png  dwuteownik         ceownik
# 130    katownik_00012-view03.png    katownik      plaskownik
# 132    katownik_00014-view04.png    katownik      plaskownik
# 133    katownik_00015-view03.png    katownik      plaskownik
# 136    katownik_00019-view03.png    katownik      plaskownik
# 140    katownik_00023-view02.png    katownik      plaskownik
# 141    katownik_00023-view03.png    katownik         ceownik
# 142    katownik_00023-view04.png    katownik      plaskownik
# 251  plaskownik_00129-view04.png  plaskownik      dwuteownik

# %% [markdown]
# ## VGG16 - transfer wiedzy - zamrożone wagi

# %%
train_gen, test_gen = preprocess_and_load_data(vgg16.preprocess_input)

pretrained_model = vgg16.VGG16(weights="imagenet", include_top=False, input_shape=(ROWS, COLS,3))
pretrained_model.trainable = False
model = prepare_model(pretrained_model)

weights_path = "vgg16_weights_with_freeze.best.hdf5"
history = fit_model(model, weights_path)
# Out:
# Found 1218 images belonging to 4 classes.
# Found 302 images belonging to 4 classes.
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 9, 9, 512)         14714688
#
#  flatten_6 (Flatten)         (None, 41472)             0
#
#  dense_12 (Dense)            (None, 128)               5308544
#
#  dense_13 (Dense)            (None, 4)                 516
#
# =================================================================
# Total params: 20,023,748
# Trainable params: 5,309,060
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/10
#
# Epoch 1: accuracy improved from -inf to 0.57225, saving model to vgg16_weights_with_freeze.best.hdf5
# 77/77 - 11s - loss: 5.3831 - accuracy: 0.5722 - 11s/epoch - 146ms/step
# Epoch 2/10
#
# Epoch 2: accuracy improved from 0.57225 to 0.70115, saving model to vgg16_weights_with_freeze.best.hdf5
# 77/77 - 9s - loss: 0.6705 - accuracy: 0.7011 - 9s/epoch - 110ms/step
# Epoch 3/10
#
# Epoch 3: accuracy improved from 0.70115 to 0.78900, saving model to vgg16_weights_with_freeze.best.hdf5
# 77/77 - 8s - loss: 0.5218 - accuracy: 0.7890 - 8s/epoch - 110ms/step
# Epoch 4/10
#
# Epoch 4: accuracy improved from 0.78900 to 0.83087, saving model to vgg16_weights_with_freeze.best.hdf5
# 77/77 - 9s - loss: 0.4136 - accuracy: 0.8309 - 9s/epoch - 113ms/step
# Epoch 5/10
#
# Epoch 5: accuracy improved from 0.83087 to 0.85140, saving model to vgg16_weights_with_freeze.best.hdf5
# 77/77 - 9s - loss: 0.4133 - accuracy: 0.8514 - 9s/epoch - 114ms/step
# Epoch 6/10
#
# Epoch 6: accuracy improved from 0.85140 to 0.88670, saving model to vgg16_weights_with_freeze.best.hdf5
# 77/77 - 9s - loss: 0.3059 - accuracy: 0.8867 - 9s/epoch - 111ms/step
# Epoch 7/10
#
# Epoch 7: accuracy did not improve from 0.88670
# 77/77 - 8s - loss: 0.3701 - accuracy: 0.8711 - 8s/epoch - 110ms/step
# Epoch 8/10
#
# Epoch 8: accuracy did not improve from 0.88670
# 77/77 - 9s - loss: 1.3008 - accuracy: 0.7126 - 9s/epoch - 110ms/step
# Epoch 9/10
#
# Epoch 9: accuracy did not improve from 0.88670
# 77/77 - 9s - loss: 0.7137 - accuracy: 0.7455 - 9s/epoch - 111ms/step
# Epoch 10/10
#
# Epoch 10: accuracy did not improve from 0.88670
# 77/77 - 9s - loss: 0.5978 - accuracy: 0.7800 - 9s/epoch - 112ms/step

# %%
show_history_plot(history)

# %%
predicts = predict(model, test_gen, weights_path)
show_confusion_matrix(train_gen, test_gen, predicts)
# Out:
# 19/19 [==============================] - 4s 225ms/step
# Accaccuracy score:  86.09271523178808

# %%
show_misclassified()
# Out:
#                            fname  true_label predicted_label
# 2       ceownik_00002-view02.png     ceownik      plaskownik
# 3       ceownik_00003-view02.png     ceownik      plaskownik
# 4       ceownik_00006-view02.png     ceownik      plaskownik
# 12      ceownik_00017-view04.png     ceownik      dwuteownik
# 13      ceownik_00018-view02.png     ceownik      dwuteownik
# 14      ceownik_00022-view01.png     ceownik      dwuteownik
# 28      ceownik_00038-view02.png     ceownik      dwuteownik
# 34      ceownik_00044-view04.png     ceownik      dwuteownik
# 42      ceownik_00055-view01.png     ceownik      plaskownik
# 46      ceownik_00063-view03.png     ceownik      dwuteownik
# 53      ceownik_00069-view02.png     ceownik      dwuteownik
# 55      ceownik_00070-view01.png     ceownik      dwuteownik
# 57      ceownik_00071-view01.png     ceownik      dwuteownik
# 58      ceownik_00072-view02.png     ceownik      dwuteownik
# 69   dwuteownik_00012-view02.png  dwuteownik      plaskownik
# 70   dwuteownik_00012-view04.png  dwuteownik      plaskownik
# 77   dwuteownik_00022-view02.png  dwuteownik      plaskownik
# 79   dwuteownik_00024-view02.png  dwuteownik      plaskownik
# 80   dwuteownik_00026-view04.png  dwuteownik      plaskownik
# 96   dwuteownik_00046-view01.png  dwuteownik      plaskownik
# 109  dwuteownik_00065-view01.png  dwuteownik      plaskownik
# 125    katownik_00003-view04.png    katownik      plaskownik
# 126    katownik_00005-view01.png    katownik      plaskownik
# 129    katownik_00009-view04.png    katownik      plaskownik
# 130    katownik_00012-view03.png    katownik      plaskownik
# 131    katownik_00013-view02.png    katownik      plaskownik
# 132    katownik_00014-view04.png    katownik      plaskownik
# 133    katownik_00015-view03.png    katownik      plaskownik
# 134    katownik_00016-view01.png    katownik      plaskownik
# 135    katownik_00018-view04.png    katownik      dwuteownik
# 136    katownik_00019-view03.png    katownik      plaskownik
# 138    katownik_00020-view02.png    katownik      plaskownik
# 140    katownik_00023-view02.png    katownik      plaskownik
# 141    katownik_00023-view03.png    katownik      plaskownik
# 142    katownik_00023-view04.png    katownik      plaskownik
# 203  plaskownik_00077-view03.png  plaskownik         ceownik
# 206  plaskownik_00081-view03.png  plaskownik      dwuteownik
# 219  plaskownik_00096-view01.png  plaskownik      dwuteownik
# 222  plaskownik_00100-view01.png  plaskownik      dwuteownik
# 224  plaskownik_00103-view01.png  plaskownik      dwuteownik
# 228  plaskownik_00109-view04.png  plaskownik      dwuteownik
# 292  plaskownik_00182-view02.png  plaskownik      dwuteownik

# %% [markdown]
# ## VGG16 - transfer wiedzy - bez zamrożenia

# %%
train_gen, test_gen = preprocess_and_load_data(vgg16.preprocess_input)

pretrained_model = vgg16.VGG16(weights="imagenet", include_top=False, input_shape=(ROWS, COLS,3))
pretrained_model.trainable = True
model = prepare_model(pretrained_model)

weights_path = "vgg16_weights_without_freeze.best.hdf5"
history = fit_model(model, weights_path)
# Out:
# Found 1218 images belonging to 4 classes.
# Found 302 images belonging to 4 classes.
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 9, 9, 512)         14714688
#
#  flatten_7 (Flatten)         (None, 41472)             0
#
#  dense_14 (Dense)            (None, 128)               5308544
#
#  dense_15 (Dense)            (None, 4)                 516
#
# =================================================================
# Total params: 20,023,748
# Trainable params: 20,023,748
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
#
# Epoch 1: accuracy improved from -inf to 0.20690, saving model to vgg16_weights_without_freeze.best.hdf5
# 77/77 - 28s - loss: nan - accuracy: 0.2069 - 28s/epoch - 360ms/step
# Epoch 2/10
#
# Epoch 2: accuracy did not improve from 0.20690
# 77/77 - 24s - loss: nan - accuracy: 0.2028 - 24s/epoch - 311ms/step
# Epoch 3/10
#
# Epoch 3: accuracy did not improve from 0.20690
# 77/77 - 24s - loss: nan - accuracy: 0.2028 - 24s/epoch - 310ms/step
# Epoch 4/10
#
# Epoch 4: accuracy did not improve from 0.20690
# 77/77 - 24s - loss: nan - accuracy: 0.2028 - 24s/epoch - 307ms/step
# Epoch 5/10
#
# Epoch 5: accuracy did not improve from 0.20690
# 77/77 - 23s - loss: nan - accuracy: 0.2028 - 23s/epoch - 299ms/step
# Epoch 6/10
#
# Epoch 6: accuracy did not improve from 0.20690
# 77/77 - 23s - loss: nan - accuracy: 0.2028 - 23s/epoch - 298ms/step
# Epoch 7/10
#
# Epoch 7: accuracy did not improve from 0.20690
# 77/77 - 23s - loss: nan - accuracy: 0.2028 - 23s/epoch - 300ms/step
# Epoch 8/10
#
# Epoch 8: accuracy did not improve from 0.20690
# 77/77 - 23s - loss: nan - accuracy: 0.2028 - 23s/epoch - 305ms/step
# Epoch 9/10
#
# Epoch 9: accuracy did not improve from 0.20690
# 77/77 - 24s - loss: nan - accuracy: 0.2028 - 24s/epoch - 308ms/step
# Epoch 10/10
#
# Epoch 10: accuracy did not improve from 0.20690
# 77/77 - 24s - loss: nan - accuracy: 0.2028 - 24s/epoch - 308ms/step

# %%
show_history_plot(history)

# %%
predicts = predict(model, test_gen, weights_path)
show_confusion_matrix(train_gen, test_gen, predicts)
# Out:
# 19/19 [==============================] - 2s 117ms/step
# Accaccuracy score:  20.198675496688743

# %%
show_misclassified()
# Out:
#                            fname  true_label predicted_label
# 61   dwuteownik_00001-view03.png  dwuteownik         ceownik
# 62   dwuteownik_00002-view01.png  dwuteownik         ceownik
# 63   dwuteownik_00002-view02.png  dwuteownik         ceownik
# 64   dwuteownik_00003-view02.png  dwuteownik         ceownik
# 65   dwuteownik_00005-view01.png  dwuteownik         ceownik
# ..                           ...         ...             ...
# 297  plaskownik_00193-view03.png  plaskownik         ceownik
# 298  plaskownik_00194-view01.png  plaskownik         ceownik
# 299  plaskownik_00197-view04.png  plaskownik         ceownik
# 300  plaskownik_00199-view02.png  plaskownik         ceownik
# 301  plaskownik_00199-view03.png  plaskownik         ceownik
#
# [241 rows x 3 columns]

# %% [markdown]
# ## VGG16 - bez transferu wiedzy

# %%
train_gen, test_gen = preprocess_and_load_data(vgg16.preprocess_input)

pretrained_model = vgg16.VGG16(weights=None, include_top=False, input_shape=(ROWS, COLS,3))
pretrained_model.trainable = True
model = prepare_model(pretrained_model)

weights_path = "vgg16_weights.best.hdf5"
history = fit_model(model, weights_path)
# Out:
# Found 1218 images belonging to 4 classes.
# Found 302 images belonging to 4 classes.
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 9, 9, 512)         14714688
#
#  flatten_8 (Flatten)         (None, 41472)             0
#
#  dense_16 (Dense)            (None, 128)               5308544
#
#  dense_17 (Dense)            (None, 4)                 516
#
# =================================================================
# Total params: 20,023,748
# Trainable params: 20,023,748
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
#
# Epoch 1: accuracy improved from -inf to 0.48030, saving model to vgg16_weights.best.hdf5
# 77/77 - 25s - loss: 1.2659 - accuracy: 0.4803 - 25s/epoch - 330ms/step
# Epoch 2/10
#
# Epoch 2: accuracy improved from 0.48030 to 0.52299, saving model to vgg16_weights.best.hdf5
# 77/77 - 25s - loss: 1.2025 - accuracy: 0.5230 - 25s/epoch - 322ms/step
# Epoch 3/10
#
# Epoch 3: accuracy did not improve from 0.52299
# 77/77 - 24s - loss: 1.1779 - accuracy: 0.5230 - 24s/epoch - 318ms/step
# Epoch 4/10
#
# Epoch 4: accuracy improved from 0.52299 to 0.52381, saving model to vgg16_weights.best.hdf5
# 77/77 - 24s - loss: 1.1579 - accuracy: 0.5238 - 24s/epoch - 317ms/step
# Epoch 5/10
#
# Epoch 5: accuracy improved from 0.52381 to 0.55501, saving model to vgg16_weights.best.hdf5
# 77/77 - 25s - loss: 1.1170 - accuracy: 0.5550 - 25s/epoch - 318ms/step
# Epoch 6/10
#
# Epoch 6: accuracy improved from 0.55501 to 0.58703, saving model to vgg16_weights.best.hdf5
# 77/77 - 24s - loss: 1.0767 - accuracy: 0.5870 - 24s/epoch - 313ms/step
# Epoch 7/10
#
# Epoch 7: accuracy improved from 0.58703 to 0.60099, saving model to vgg16_weights.best.hdf5
# 77/77 - 25s - loss: 1.0145 - accuracy: 0.6010 - 25s/epoch - 320ms/step
# Epoch 8/10
#
# Epoch 8: accuracy improved from 0.60099 to 0.61823, saving model to vgg16_weights.best.hdf5
# 77/77 - 25s - loss: 0.9564 - accuracy: 0.6182 - 25s/epoch - 331ms/step
# Epoch 9/10
#
# Epoch 9: accuracy improved from 0.61823 to 0.63711, saving model to vgg16_weights.best.hdf5
# 77/77 - 26s - loss: 0.9048 - accuracy: 0.6371 - 26s/epoch - 344ms/step
# Epoch 10/10
#
# Epoch 10: accuracy improved from 0.63711 to 0.68801, saving model to vgg16_weights.best.hdf5
# 77/77 - 26s - loss: 0.7790 - accuracy: 0.6880 - 26s/epoch - 339ms/step

# %%
show_history_plot(history)

# %%
predicts = predict(model, test_gen, weights_path)
show_confusion_matrix(train_gen, test_gen, predicts)
# Out:
# 19/19 [==============================] - 2s 127ms/step
# Accaccuracy score:  62.58278145695364

# %%
show_misclassified()
# Out:
#                          fname true_label predicted_label
# 0     ceownik_00001-view01.png    ceownik      plaskownik
# 1     ceownik_00001-view03.png    ceownik      plaskownik
# 2     ceownik_00002-view02.png    ceownik      plaskownik
# 3     ceownik_00003-view02.png    ceownik      plaskownik
# 4     ceownik_00006-view02.png    ceownik      plaskownik
# ..                         ...        ...             ...
# 137  katownik_00020-view01.png   katownik      plaskownik
# 138  katownik_00020-view02.png   katownik      plaskownik
# 140  katownik_00023-view02.png   katownik      plaskownik
# 141  katownik_00023-view03.png   katownik      plaskownik
# 142  katownik_00023-view04.png   katownik      plaskownik
#
# [113 rows x 3 columns]
