# %% [markdown]
# # Etap 1

# %% [markdown]
# Celem notatnika jest przegląd kilku dostępnych architektur konwolucyjnych sieci neuronowych i przetestowanie ich zastosowania do rozpoznawania elementów konstrukcyjnych. Sprawdzano również zastosowanie transferu wiedzy z modeli wytrenowanych na zbiorze danych ImageNet. Zbiór ten składa się z milionów obrazów ręcznie zaklasyfikowanych do co najmniej 20 tysięcy klas.
#
# Wybrane architektury:
# - ResNet50 - rozmiar wejściowy 224x224
# - Xception - rozmiar wejściowy 299x299
# - VGG16 - rozmiar wejściowy 224x224
#
# Biblioteka Keras udostępnia modele dla każdej wyżej wymienionej architektury oraz gotowe wagi z możliwością ich zamrożenia podczas treningu na własnych danych.
#
# #### Zbiór danych wykorzystany w testach
# Na podstawie dostarczonych plików .stl wygenerowano 1520 obrazów o rozdzielczości 300x300 pikseli. Dla każdego pliku .stl wygenerowano 4 obrazy pod różnym kątem.
# Ograniczono się do czterech klas elementów:
# - ceownik - 308 plików
# - dwuteownik - 324 plików
# - katownik - 92 plików
# - plaskownik - 796 plików
#
# Całą pulę podzielono na zbiór treningowy i testowy w stosunku 80:20 dla każdej klasy.
#
# #### Przebieg testów
# Dla każdej architektury wytrenowano model trzykrotnie:
# - Model zainicjowany wytrenowanymi wagi z zablokowaną możliwością edycji
# - Model zainicjowany wytrenowanymi wagi z możliwością edycji
# - Model zainicjowany losowymi wagami
#
# Do gotowych modeli dodano dwie warstwy zwracające prawdopodobieństwo przynależności do każdej z klas. Każdy model uruchomiono z wykorzystaniem identycznych hiperparametrów. W celu porównania skuteczności wygenerowano macierze pomyłek oraz obliczono miary trafności.

# %% [markdown]
# # Import zależności

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.models import Model
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau, TensorBoard
from keras import optimizers, losses, activations, models
from keras.layers import Convolution2D, Dense, Input, Flatten, Dropout, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D, Concatenate
from tensorflow.keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

import tensorflow.keras.applications.resnet50 as resnet50
import tensorflow.keras.applications.xception as xception
import tensorflow.keras.applications.vgg16 as vgg16
ROWS=300
COLS=300

# %% [markdown]
# # Definicje funkcji

# %%
def preprocess_and_load_data(preprocessing_function, batch_size = 16):
    resnet50_idg = ImageDataGenerator(preprocessing_function=preprocessing_function)

    train_gen = resnet50_idg.flow_from_directory(
        'STL_IMAGES/train',
        target_size=(ROWS, COLS),
        batch_size = batch_size
    )

    test_gen = resnet50_idg.flow_from_directory(
        'STL_IMAGES/test',
        target_size=(ROWS, COLS),
        batch_size = batch_size,
        shuffle = False,
        class_mode='binary'
    )
    return train_gen, test_gen

def prepare_model(pretrained_model):
    nclass = len(train_gen.class_indices)
    resnet_model = Sequential()
    resnet_model.add(pretrained_model)
    resnet_model.add(Flatten())
    resnet_model.add(Dense(128, activation='relu'))
    resnet_model.add(Dense(nclass, activation='softmax'))

    model = resnet_model
    model.compile(loss='categorical_crossentropy', 
                  optimizer=SGD(learning_rate=0.005),
                  metrics=['accuracy'])
    model.summary()
    return model

def fit_model(model, weights_path):
    checkpoint = ModelCheckpoint(weights_path, monitor='accuracy', verbose=1, save_best_only=True, mode='max')
    early = EarlyStopping(monitor="accuracy", mode="max", patience=10)
    callbacks_list = [checkpoint, early]
    history = model.fit(train_gen, 
                        epochs=10,
                        shuffle=True, 
                        verbose=2,
                        callbacks=callbacks_list)
    return history

def show_history_plot(history):
    sns.set(font_scale = 1)
    fig1 = plt.gcf()
    plt.plot(history.history['accuracy'])
    plt.grid()
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epochs')
    plt.legend(['accuracy'])
    plt.show()
    
def predict(model, test_gen, weights_path):
    model.load_weights(weights_path)
    predicts = model.predict(test_gen, verbose = True, workers = 2)
    return predicts

def show_confusion_matrix(train_gen, test_gen, predicts):
    sns.set(font_scale = 2)
    label_names = list(train_gen.class_indices)
    y_true = test_gen.labels
    y_pred = np.argmax(predicts, axis=1)

    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize = (15, 15))

    ax= plt.subplot()
    sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', ax=ax)

    ax.set_xlabel('Predicted labels')
    ax.set_ylabel('True labels')
    ax.set_title('Confusion Matrix')
    ax.xaxis.set_ticklabels(label_names)
    ax.yaxis.set_ticklabels(label_names)

    print("Accaccuracy score: ", accuracy_score(y_true, y_pred)*100)
    
def show_misclassified():
    predicts_top1 = np.argmax(predicts, axis=1)
    label_index = {v: k for k,v in train_gen.class_indices.items()}
    predicts_top1 = [label_index[p] for p in predicts_top1]

    df = pd.DataFrame(columns=['fname', 'true_label', 'predicted_label'])
    df['fname'] = [os.path.basename(x) for x in test_gen.filenames]
    df['true_label'] = [label_index[p] for p in test_gen.labels]
    df['predicted_label'] = predicts_top1

    return df.iloc[np.where((df['true_label'] != df['predicted_label']))]

# %% [markdown]
# # Prównanie istniejących rozwiązań
# ## ResNet50 - transfer wiedzy - zamrożone wagi

# %%
train_gen, test_gen = preprocess_and_load_data(resnet50.preprocess_input)
# Out:
# Found 1218 images belonging to 4 classes.
# Found 302 images belonging to 4 classes.

# %%
pretrained_model = resnet50.ResNet50(weights='imagenet', include_top=False, input_shape=(ROWS, COLS,3))
pretrained_model.trainable = False
model = prepare_model(pretrained_model)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 10, 10, 2048)      23587712
#
#  flatten (Flatten)           (None, 204800)            0
#
#  dense (Dense)               (None, 128)               26214528
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 49,802,756
# Trainable params: 26,215,044
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
weights_path = "resnet50_weights_with_freeze.best.hdf5"
history = fit_model(model, weights_path)
# Out:
# Epoch 1/10
#
# Epoch 1: accuracy improved from -inf to 0.49507, saving model to resnet50_weights_with_freeze.best.hdf5
# 77/77 - 10s - loss: 9.2473 - accuracy: 0.4951 - 10s/epoch - 126ms/step
# Epoch 2/10
#
# Epoch 2: accuracy improved from 0.49507 to 0.70033, saving model to resnet50_weights_with_freeze.best.hdf5
# 77/77 - 6s - loss: 0.8530 - accuracy: 0.7003 - 6s/epoch - 74ms/step
# Epoch 3/10
#
# Epoch 3: accuracy improved from 0.70033 to 0.72496, saving model to resnet50_weights_with_freeze.best.hdf5
# 77/77 - 6s - loss: 0.7616 - accuracy: 0.7250 - 6s/epoch - 72ms/step
# Epoch 4/10
#
# Epoch 4: accuracy improved from 0.72496 to 0.73481, saving model to resnet50_weights_with_freeze.best.hdf5
# 77/77 - 6s - loss: 0.7284 - accuracy: 0.7348 - 6s/epoch - 72ms/step
# Epoch 5/10
#
# Epoch 5: accuracy improved from 0.73481 to 0.73892, saving model to resnet50_weights_with_freeze.best.hdf5
# 77/77 - 6s - loss: 0.6960 - accuracy: 0.7389 - 6s/epoch - 73ms/step
# Epoch 6/10
#
# Epoch 6: accuracy did not improve from 0.73892
# 77/77 - 5s - loss: 0.7012 - accuracy: 0.7373 - 5s/epoch - 68ms/step
# Epoch 7/10
#
# Epoch 7: accuracy improved from 0.73892 to 0.74713, saving model to resnet50_weights_with_freeze.best.hdf5
# 77/77 - 6s - loss: 0.6542 - accuracy: 0.7471 - 6s/epoch - 72ms/step
# Epoch 8/10
#
# Epoch 8: accuracy improved from 0.74713 to 0.75287, saving model to resnet50_weights_with_freeze.best.hdf5
# 77/77 - 6s - loss: 0.6443 - accuracy: 0.7529 - 6s/epoch - 72ms/step
# Epoch 9/10
#
# Epoch 9: accuracy did not improve from 0.75287
# 77/77 - 5s - loss: 0.6513 - accuracy: 0.7447 - 5s/epoch - 68ms/step
# Epoch 10/10
#
# Epoch 10: accuracy improved from 0.75287 to 0.76190, saving model to resnet50_weights_with_freeze.best.hdf5
# 77/77 - 6s - loss: 0.6007 - accuracy: 0.7619 - 6s/epoch - 72ms/step

# %%
show_history_plot(history)

# %%
predicts = predict(model, test_gen, weights_path)
show_confusion_matrix(train_gen, test_gen, predicts)
# Out:
# 19/19 [==============================] - 3s 110ms/step
# Accaccuracy score:  72.84768211920529

# %%
show_misclassified()
# Out:
#                          fname true_label predicted_label
# 0     ceownik_00001-view01.png    ceownik      dwuteownik
# 1     ceownik_00001-view03.png    ceownik      plaskownik
# 2     ceownik_00002-view02.png    ceownik      plaskownik
# 3     ceownik_00003-view02.png    ceownik      plaskownik
# 4     ceownik_00006-view02.png    ceownik      plaskownik
# ..                         ...        ...             ...
# 136  katownik_00019-view03.png   katownik      plaskownik
# 138  katownik_00020-view02.png   katownik      plaskownik
# 140  katownik_00023-view02.png   katownik      dwuteownik
# 141  katownik_00023-view03.png   katownik      dwuteownik
# 142  katownik_00023-view04.png   katownik      plaskownik
#
# [82 rows x 3 columns]

# %% [markdown]
# ## ResNet50 - transfer wiedzy - bez zamrożenia

# %%
train_gen, test_gen = preprocess_and_load_data(resnet50.preprocess_input)

pretrained_model = resnet50.ResNet50(weights='imagenet', include_top=False, input_shape=(ROWS, COLS,3))
pretrained_model.trainable = True
model = prepare_model(pretrained_model)

weights_path = "resnet50_weights_without_freeze.best.hdf5"
history = fit_model(model, weights_path)
# Out:
# Found 1218 images belonging to 4 classes.
# Found 302 images belonging to 4 classes.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 10, 10, 2048)      23587712
#
#  flatten_1 (Flatten)         (None, 204800)            0
#
#  dense_2 (Dense)             (None, 128)               26214528
#
#  dense_3 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 49,802,756
# Trainable params: 49,749,636
# Non-trainable params: 53,120
# _________________________________________________________________
# Epoch 1/10
#
# Epoch 1: accuracy improved from -inf to 0.61494, saving model to resnet50_weights_without_freeze.best.hdf5
# 77/77 - 22s - loss: 2.1107 - accuracy: 0.6149 - 22s/epoch - 280ms/step
# Epoch 2/10
#
# Epoch 2: accuracy improved from 0.61494 to 0.75452, saving model to resnet50_weights_without_freeze.best.hdf5
# 77/77 - 17s - loss: 0.6760 - accuracy: 0.7545 - 17s/epoch - 222ms/step
# Epoch 3/10
#
# Epoch 3: accuracy improved from 0.75452 to 0.85140, saving model to resnet50_weights_without_freeze.best.hdf5
# 77/77 - 17s - loss: 0.3948 - accuracy: 0.8514 - 17s/epoch - 224ms/step
# Epoch 4/10
#
# Epoch 4: accuracy improved from 0.85140 to 0.90558, saving model to resnet50_weights_without_freeze.best.hdf5
# 77/77 - 17s - loss: 0.2777 - accuracy: 0.9056 - 17s/epoch - 221ms/step
# Epoch 5/10
#
# Epoch 5: accuracy improved from 0.90558 to 0.91872, saving model to resnet50_weights_without_freeze.best.hdf5
# 77/77 - 17s - loss: 0.2289 - accuracy: 0.9187 - 17s/epoch - 221ms/step
# Epoch 6/10
#
# Epoch 6: accuracy did not improve from 0.91872
# 77/77 - 17s - loss: 0.2998 - accuracy: 0.8990 - 17s/epoch - 216ms/step
# Epoch 7/10
#
# Epoch 7: accuracy did not improve from 0.91872
# 77/77 - 17s - loss: 0.4647 - accuracy: 0.8342 - 17s/epoch - 217ms/step
# Epoch 8/10
#
# Epoch 8: accuracy did not improve from 0.91872
# 77/77 - 17s - loss: 0.2462 - accuracy: 0.9089 - 17s/epoch - 217ms/step
# Epoch 9/10
#
# Epoch 9: accuracy improved from 0.91872 to 0.92857, saving model to resnet50_weights_without_freeze.best.hdf5
# 77/77 - 17s - loss: 0.2037 - accuracy: 0.9286 - 17s/epoch - 222ms/step
# Epoch 10/10
#
# Epoch 10: accuracy improved from 0.92857 to 0.96141, saving model to resnet50_weights_without_freeze.best.hdf5
# 77/77 - 17s - loss: 0.1084 - accuracy: 0.9614 - 17s/epoch - 222ms/step

# %%
show_history_plot(history)

# %%
predicts = predict(model, test_gen, weights_path)
show_confusion_matrix(train_gen, test_gen, predicts)
# Out:
# 19/19 [==============================] - 2s 72ms/step
# Accaccuracy score:  93.37748344370861

# %%
show_misclassified()
# Out:
#                            fname  true_label predicted_label
# 2       ceownik_00002-view02.png     ceownik      dwuteownik
# 3       ceownik_00003-view02.png     ceownik      dwuteownik
# 4       ceownik_00006-view02.png     ceownik      plaskownik
# 39      ceownik_00051-view01.png     ceownik      plaskownik
# 40      ceownik_00051-view02.png     ceownik      plaskownik
# 42      ceownik_00055-view01.png     ceownik      dwuteownik
# 46      ceownik_00063-view03.png     ceownik      plaskownik
# 78   dwuteownik_00023-view01.png  dwuteownik      plaskownik
# 81   dwuteownik_00027-view04.png  dwuteownik      plaskownik
# 92   dwuteownik_00042-view03.png  dwuteownik      plaskownik
# 96   dwuteownik_00046-view01.png  dwuteownik      plaskownik
# 111  dwuteownik_00069-view02.png  dwuteownik         ceownik
# 130    katownik_00012-view03.png    katownik      plaskownik
# 133    katownik_00015-view03.png    katownik      plaskownik
# 136    katownik_00019-view03.png    katownik      plaskownik
# 138    katownik_00020-view02.png    katownik      plaskownik
# 140    katownik_00023-view02.png    katownik      dwuteownik
# 141    katownik_00023-view03.png    katownik      dwuteownik
# 142    katownik_00023-view04.png    katownik      plaskownik
# 229  plaskownik_00110-view01.png  plaskownik      dwuteownik

# %% [markdown]
# ## ResNet50 - bez transferu wiedzy

# %%
train_gen, test_gen = preprocess_and_load_data(resnet50.preprocess_input)

pretrained_model = resnet50.ResNet50(weights=None, include_top=False, input_shape=(ROWS, COLS,3))
pretrained_model.trainable = True
model = prepare_model(pretrained_model)

weights_path = "resnet50_weights.best.hdf5"
history = fit_model(model, weights_path)
# Out:
# Found 1218 images belonging to 4 classes.
# Found 302 images belonging to 4 classes.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 10, 10, 2048)      23587712
#
#  flatten_2 (Flatten)         (None, 204800)            0
#
#  dense_4 (Dense)             (None, 128)               26214528
#
#  dense_5 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 49,802,756
# Trainable params: 49,749,636
# Non-trainable params: 53,120
# _________________________________________________________________
# Epoch 1/10
#
# Epoch 1: accuracy improved from -inf to 0.50821, saving model to resnet50_weights.best.hdf5
# 77/77 - 20s - loss: 10.0227 - accuracy: 0.5082 - 20s/epoch - 254ms/step
# Epoch 2/10
#
# Epoch 2: accuracy improved from 0.50821 to 0.52299, saving model to resnet50_weights.best.hdf5
# 77/77 - 17s - loss: 1.1759 - accuracy: 0.5230 - 17s/epoch - 222ms/step
# Epoch 3/10
#
# Epoch 3: accuracy did not improve from 0.52299
# 77/77 - 17s - loss: 1.3283 - accuracy: 0.5230 - 17s/epoch - 216ms/step
# Epoch 4/10
#
# Epoch 4: accuracy did not improve from 0.52299
# 77/77 - 17s - loss: 1.3179 - accuracy: 0.5230 - 17s/epoch - 216ms/step
# Epoch 5/10
#
# Epoch 5: accuracy did not improve from 0.52299
# 77/77 - 17s - loss: 1.2923 - accuracy: 0.5222 - 17s/epoch - 216ms/step
# Epoch 6/10
#
# Epoch 6: accuracy did not improve from 0.52299
# 77/77 - 17s - loss: 1.2216 - accuracy: 0.5230 - 17s/epoch - 218ms/step
# Epoch 7/10
#
# Epoch 7: accuracy did not improve from 0.52299
# 77/77 - 17s - loss: 1.1823 - accuracy: 0.5181 - 17s/epoch - 219ms/step
# Epoch 8/10
#
# Epoch 8: accuracy did not improve from 0.52299
# 77/77 - 17s - loss: 1.2539 - accuracy: 0.5230 - 17s/epoch - 218ms/step
# Epoch 9/10
#
# Epoch 9: accuracy did not improve from 0.52299
# 77/77 - 17s - loss: 1.2383 - accuracy: 0.5230 - 17s/epoch - 217ms/step
# Epoch 10/10
#
# Epoch 10: accuracy did not improve from 0.52299
# 77/77 - 17s - loss: 1.2260 - accuracy: 0.5230 - 17s/epoch - 217ms/step

# %%
show_history_plot(history)

# %%
predicts = predict(model, test_gen, weights_path)
show_confusion_matrix(train_gen, test_gen, predicts)
# Out:
# 19/19 [==============================] - 2s 72ms/step
# Accaccuracy score:  52.64900662251656

# %%
show_misclassified()
# Out:
#                          fname true_label predicted_label
# 0     ceownik_00001-view01.png    ceownik      plaskownik
# 1     ceownik_00001-view03.png    ceownik      plaskownik
# 2     ceownik_00002-view02.png    ceownik      plaskownik
# 3     ceownik_00003-view02.png    ceownik      plaskownik
# 4     ceownik_00006-view02.png    ceownik      plaskownik
# ..                         ...        ...             ...
# 138  katownik_00020-view02.png   katownik      plaskownik
# 139  katownik_00022-view03.png   katownik      plaskownik
# 140  katownik_00023-view02.png   katownik      plaskownik
# 141  katownik_00023-view03.png   katownik      plaskownik
# 142  katownik_00023-view04.png   katownik      plaskownik
#
# [143 rows x 3 columns]

# %% [markdown]
# ## Xception - transfer wiedzy - zamrożone wagi

# %%
train_gen, test_gen = preprocess_and_load_data(xception.preprocess_input)

pretrained_model = xception.Xception(weights="imagenet", include_top=False, input_shape=(ROWS, COLS,3))
pretrained_model.trainable = False
model = prepare_model(pretrained_model)

weights_path = "xception_weights_with_freeze.best.hdf5"
history = fit_model(model, weights_path)
# Out:
# Found 1218 images belonging to 4 classes.
# Found 302 images belonging to 4 classes.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 10, 10, 2048)      20861480
#
#  flatten_3 (Flatten)         (None, 204800)            0
#
#  dense_6 (Dense)             (None, 128)               26214528
#
#  dense_7 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 47,076,524
# Trainable params: 26,215,044
# Non-trainable params: 20,861,480
# _________________________________________________________________
# Epoch 1/10
#
# Epoch 1: accuracy improved from -inf to 0.72414, saving model to xception_weights_with_freeze.best.hdf5
# 77/77 - 8s - loss: 0.8983 - accuracy: 0.7241 - 8s/epoch - 110ms/step
# Epoch 2/10
#
# Epoch 2: accuracy improved from 0.72414 to 0.86864, saving model to xception_weights_with_freeze.best.hdf5
# 77/77 - 6s - loss: 0.3638 - accuracy: 0.8686 - 6s/epoch - 83ms/step
# Epoch 3/10
#
# Epoch 3: accuracy improved from 0.86864 to 0.91379, saving model to xception_weights_with_freeze.best.hdf5
# 77/77 - 7s - loss: 0.2626 - accuracy: 0.9138 - 7s/epoch - 88ms/step
# Epoch 4/10
#
# Epoch 4: accuracy improved from 0.91379 to 0.93514, saving model to xception_weights_with_freeze.best.hdf5
# 77/77 - 7s - loss: 0.2048 - accuracy: 0.9351 - 7s/epoch - 85ms/step
# Epoch 5/10
#
# Epoch 5: accuracy improved from 0.93514 to 0.94581, saving model to xception_weights_with_freeze.best.hdf5
# 77/77 - 7s - loss: 0.1666 - accuracy: 0.9458 - 7s/epoch - 87ms/step
# Epoch 6/10
#
# Epoch 6: accuracy improved from 0.94581 to 0.95813, saving model to xception_weights_with_freeze.best.hdf5
# 77/77 - 7s - loss: 0.1367 - accuracy: 0.9581 - 7s/epoch - 86ms/step
# Epoch 7/10
#
# Epoch 7: accuracy improved from 0.95813 to 0.96634, saving model to xception_weights_with_freeze.best.hdf5
# 77/77 - 7s - loss: 0.1152 - accuracy: 0.9663 - 7s/epoch - 86ms/step
# Epoch 8/10
#
# Epoch 8: accuracy improved from 0.96634 to 0.97373, saving model to xception_weights_with_freeze.best.hdf5
# 77/77 - 7s - loss: 0.0909 - accuracy: 0.9737 - 7s/epoch - 86ms/step
# Epoch 9/10
#
# Epoch 9: accuracy did not improve from 0.97373
# 77/77 - 6s - loss: 0.1202 - accuracy: 0.9622 - 6s/epoch - 80ms/step
# Epoch 10/10
#
# Epoch 10: accuracy improved from 0.97373 to 0.97537, saving model to xception_weights_with_freeze.best.hdf5
# 77/77 - 7s - loss: 0.0784 - accuracy: 0.9754 - 7s/epoch - 86ms/step

# %%
show_history_plot(history)

# %%
predicts = predict(model, test_gen, weights_path)
show_confusion_matrix(train_gen, test_gen, predicts)
# Out:
# 19/19 [==============================] - 2s 111ms/step
# Accaccuracy score:  93.70860927152319

# %%
show_misclassified()
# Out:
#                            fname  true_label predicted_label
# 0       ceownik_00001-view01.png     ceownik        katownik
# 3       ceownik_00003-view02.png     ceownik      dwuteownik
# 12      ceownik_00017-view04.png     ceownik      dwuteownik
# 58      ceownik_00072-view02.png     ceownik      dwuteownik
# 60      ceownik_00076-view01.png     ceownik        katownik
# 79   dwuteownik_00024-view02.png  dwuteownik      plaskownik
# 92   dwuteownik_00042-view03.png  dwuteownik      plaskownik
# 111  dwuteownik_00069-view02.png  dwuteownik         ceownik
# 122  dwuteownik_00082-view04.png  dwuteownik      plaskownik
# 125    katownik_00003-view04.png    katownik      plaskownik
# 130    katownik_00012-view03.png    katownik      plaskownik
# 133    katownik_00015-view03.png    katownik      plaskownik
# 140    katownik_00023-view02.png    katownik      dwuteownik
# 141    katownik_00023-view03.png    katownik      plaskownik
# 142    katownik_00023-view04.png    katownik      plaskownik
# 213  plaskownik_00089-view04.png  plaskownik         ceownik
# 221  plaskownik_00098-view04.png  plaskownik      dwuteownik
# 292  plaskownik_00182-view02.png  plaskownik      dwuteownik
# 300  plaskownik_00199-view02.png  plaskownik      dwuteownik

# %% [markdown]
# ## Xception - transfer wiedzy - bez zamrożenia

# %%
train_gen, test_gen = preprocess_and_load_data(xception.preprocess_input)

pretrained_model = xception.Xception(weights="imagenet", include_top=False, input_shape=(ROWS, COLS,3))
pretrained_model.trainable = True
model = prepare_model(pretrained_model)

weights_path = "xception_weights_without_freeze.best.hdf5"
history = fit_model(model, weights_path)
# Out:
# Found 1218 images belonging to 4 classes.
# Found 302 images belonging to 4 classes.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 10, 10, 2048)      20861480
#
#  flatten_4 (Flatten)         (None, 204800)            0
#
#  dense_8 (Dense)             (None, 128)               26214528
#
#  dense_9 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 47,076,524
# Trainable params: 47,021,996
# Non-trainable params: 54,528
# _________________________________________________________________
# Epoch 1/10
#
# Epoch 1: accuracy improved from -inf to 0.66502, saving model to xception_weights_without_freeze.best.hdf5
# 77/77 - 35s - loss: 0.9470 - accuracy: 0.6650 - 35s/epoch - 453ms/step
# Epoch 2/10
#
# Epoch 2: accuracy improved from 0.66502 to 0.86700, saving model to xception_weights_without_freeze.best.hdf5
# 77/77 - 32s - loss: 0.3975 - accuracy: 0.8670 - 32s/epoch - 414ms/step
# Epoch 3/10
#
# Epoch 3: accuracy improved from 0.86700 to 0.90558, saving model to xception_weights_without_freeze.best.hdf5
# 77/77 - 32s - loss: 0.2974 - accuracy: 0.9056 - 32s/epoch - 416ms/step
# Epoch 4/10
#
# Epoch 4: accuracy improved from 0.90558 to 0.94417, saving model to xception_weights_without_freeze.best.hdf5
# 77/77 - 32s - loss: 0.1937 - accuracy: 0.9442 - 32s/epoch - 420ms/step
# Epoch 5/10
#
# Epoch 5: accuracy improved from 0.94417 to 0.96223, saving model to xception_weights_without_freeze.best.hdf5
# 77/77 - 33s - loss: 0.1151 - accuracy: 0.9622 - 33s/epoch - 423ms/step
# Epoch 6/10
#
# Epoch 6: accuracy improved from 0.96223 to 0.97701, saving model to xception_weights_without_freeze.best.hdf5
# 77/77 - 32s - loss: 0.0659 - accuracy: 0.9770 - 32s/epoch - 415ms/step
# Epoch 7/10
#
# Epoch 7: accuracy improved from 0.97701 to 0.98440, saving model to xception_weights_without_freeze.best.hdf5
# 77/77 - 32s - loss: 0.0438 - accuracy: 0.9844 - 32s/epoch - 414ms/step
# Epoch 8/10
#
# Epoch 8: accuracy improved from 0.98440 to 0.99507, saving model to xception_weights_without_freeze.best.hdf5
# 77/77 - 32s - loss: 0.0241 - accuracy: 0.9951 - 32s/epoch - 419ms/step
# Epoch 9/10
#
# Epoch 9: accuracy did not improve from 0.99507
# 77/77 - 32s - loss: 0.0373 - accuracy: 0.9869 - 32s/epoch - 417ms/step
# Epoch 10/10
#
# Epoch 10: accuracy did not improve from 0.99507
# 77/77 - 32s - loss: 0.0241 - accuracy: 0.9926 - 32s/epoch - 414ms/step

# %%
show_history_plot(history)

# %%
predicts = predict(model, test_gen, weights_path)
show_confusion_matrix(train_gen, test_gen, predicts)
# Out:
# 19/19 [==============================] - 2s 85ms/step
# Accaccuracy score:  94.70198675496688

# %%
show_misclassified()
# Out:
#                            fname  true_label predicted_label
# 2       ceownik_00002-view02.png     ceownik      plaskownik
# 3       ceownik_00003-view02.png     ceownik      plaskownik
# 42      ceownik_00055-view01.png     ceownik      plaskownik
# 46      ceownik_00063-view03.png     ceownik      dwuteownik
# 79   dwuteownik_00024-view02.png  dwuteownik      plaskownik
# 81   dwuteownik_00027-view04.png  dwuteownik      plaskownik
# 96   dwuteownik_00046-view01.png  dwuteownik      plaskownik
# 117  dwuteownik_00077-view01.png  dwuteownik         ceownik
# 122  dwuteownik_00082-view04.png  dwuteownik      plaskownik
# 130    katownik_00012-view03.png    katownik      plaskownik
# 133    katownik_00015-view03.png    katownik      plaskownik
# 140    katownik_00023-view02.png    katownik      dwuteownik
# 141    katownik_00023-view03.png    katownik      dwuteownik
# 142    katownik_00023-view04.png    katownik      plaskownik
# 206  plaskownik_00081-view03.png  plaskownik      dwuteownik
# 285  plaskownik_00166-view01.png  plaskownik         ceownik

# %% [markdown]
# ## Xception - bez transferu wiedzy

# %%
train_gen, test_gen = preprocess_and_load_data(xception.preprocess_input)

pretrained_model = xception.Xception(weights=None, include_top=False, input_shape=(ROWS, COLS,3))
pretrained_model.trainable = True
model = prepare_model(pretrained_model)

weights_path = "xception_weights.best.hdf5"
history = fit_model(model, weights_path)
# Out:
# Found 1218 images belonging to 4 classes.
# Found 302 images belonging to 4 classes.
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 10, 10, 2048)      20861480
#
#  flatten_5 (Flatten)         (None, 204800)            0
#
#  dense_10 (Dense)            (None, 128)               26214528
#
#  dense_11 (Dense)            (None, 4)                 516
#
# =================================================================
# Total params: 47,076,524
# Trainable params: 47,021,996
# Non-trainable params: 54,528
# _________________________________________________________________
# Epoch 1/10
#
# Epoch 1: accuracy improved from -inf to 0.55747, saving model to xception_weights.best.hdf5
# 77/77 - 34s - loss: 1.1930 - accuracy: 0.5575 - 34s/epoch - 445ms/step
# Epoch 2/10
#
# Epoch 2: accuracy improved from 0.55747 to 0.74056, saving model to xception_weights.best.hdf5
# 77/77 - 32s - loss: 0.6990 - accuracy: 0.7406 - 32s/epoch - 412ms/step
# Epoch 3/10
#
# Epoch 3: accuracy improved from 0.74056 to 0.85386, saving model to xception_weights.best.hdf5
# 77/77 - 32s - loss: 0.4492 - accuracy: 0.8539 - 32s/epoch - 418ms/step
# Epoch 4/10
#
# Epoch 4: accuracy improved from 0.85386 to 0.95813, saving model to xception_weights.best.hdf5
# 77/77 - 32s - loss: 0.1758 - accuracy: 0.9581 - 32s/epoch - 420ms/step
# Epoch 5/10
#
# Epoch 5: accuracy did not improve from 0.95813
# 77/77 - 32s - loss: 0.2316 - accuracy: 0.9351 - 32s/epoch - 412ms/step
# Epoch 6/10
#
# Epoch 6: accuracy improved from 0.95813 to 0.96962, saving model to xception_weights.best.hdf5
# 77/77 - 33s - loss: 0.1449 - accuracy: 0.9696 - 33s/epoch - 431ms/step
# Epoch 7/10
#
# Epoch 7: accuracy improved from 0.96962 to 0.99261, saving model to xception_weights.best.hdf5
# 77/77 - 38s - loss: 0.0348 - accuracy: 0.9926 - 38s/epoch - 492ms/step
# Epoch 8/10
#
# Epoch 8: accuracy improved from 0.99261 to 0.99754, saving model to xception_weights.best.hdf5
# 77/77 - 36s - loss: 0.0195 - accuracy: 0.9975 - 36s/epoch - 473ms/step
# Epoch 9/10
#
# Epoch 9: accuracy did not improve from 0.99754
# 77/77 - 36s - loss: 0.0164 - accuracy: 0.9959 - 36s/epoch - 462ms/step
# Epoch 10/10
#
# Epoch 10: accuracy did not improve from 0.99754
# 77/77 - 36s - loss: 0.0175 - accuracy: 0.9967 - 36s/epoch - 469ms/step

# %%
show_history_plot(history)

# %%
predicts = predict(model, test_gen, weights_path)
show_confusion_matrix(train_gen, test_gen, predicts)
# Out:
# 19/19 [==============================] - 2s 88ms/step
# Accaccuracy score:  52.64900662251656

# %%
show_misclassified()
# Out:
#                          fname true_label predicted_label
# 0     ceownik_00001-view01.png    ceownik      plaskownik
# 1     ceownik_00001-view03.png    ceownik      plaskownik
# 2     ceownik_00002-view02.png    ceownik      plaskownik
# 3     ceownik_00003-view02.png    ceownik      plaskownik
# 4     ceownik_00006-view02.png    ceownik      plaskownik
# ..                         ...        ...             ...
# 138  katownik_00020-view02.png   katownik      plaskownik
# 139  katownik_00022-view03.png   katownik      plaskownik
# 140  katownik_00023-view02.png   katownik      plaskownik
# 141  katownik_00023-view03.png   katownik      plaskownik
# 142  katownik_00023-view04.png   katownik      plaskownik
#
# [143 rows x 3 columns]

# %% [markdown]
# ## VGG16 - transfer wiedzy - zamrożone wagi

# %%
train_gen, test_gen = preprocess_and_load_data(vgg16.preprocess_input)

pretrained_model = vgg16.VGG16(weights="imagenet", include_top=False, input_shape=(ROWS, COLS,3))
pretrained_model.trainable = False
model = prepare_model(pretrained_model)

weights_path = "vgg16_weights_with_freeze.best.hdf5"
history = fit_model(model, weights_path)
# Out:
# Found 1218 images belonging to 4 classes.
# Found 302 images belonging to 4 classes.
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 9, 9, 512)         14714688
#
#  flatten_6 (Flatten)         (None, 41472)             0
#
#  dense_12 (Dense)            (None, 128)               5308544
#
#  dense_13 (Dense)            (None, 4)                 516
#
# =================================================================
# Total params: 20,023,748
# Trainable params: 5,309,060
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/10
#
# Epoch 1: accuracy improved from -inf to 0.65107, saving model to vgg16_weights_with_freeze.best.hdf5
# 77/77 - 11s - loss: 4.4690 - accuracy: 0.6511 - 11s/epoch - 144ms/step
# Epoch 2/10
#
# Epoch 2: accuracy improved from 0.65107 to 0.83744, saving model to vgg16_weights_with_freeze.best.hdf5
# 77/77 - 8s - loss: 0.4478 - accuracy: 0.8374 - 8s/epoch - 109ms/step
# Epoch 3/10
#
# Epoch 3: accuracy improved from 0.83744 to 0.87356, saving model to vgg16_weights_with_freeze.best.hdf5
# 77/77 - 8s - loss: 0.3384 - accuracy: 0.8736 - 8s/epoch - 106ms/step
# Epoch 4/10
#
# Epoch 4: accuracy improved from 0.87356 to 0.89819, saving model to vgg16_weights_with_freeze.best.hdf5
# 77/77 - 8s - loss: 0.2815 - accuracy: 0.8982 - 8s/epoch - 106ms/step
# Epoch 5/10
#
# Epoch 5: accuracy improved from 0.89819 to 0.93350, saving model to vgg16_weights_with_freeze.best.hdf5
# 77/77 - 8s - loss: 0.1886 - accuracy: 0.9335 - 8s/epoch - 108ms/step
# Epoch 6/10
#
# Epoch 6: accuracy improved from 0.93350 to 0.94171, saving model to vgg16_weights_with_freeze.best.hdf5
# 77/77 - 9s - loss: 0.1710 - accuracy: 0.9417 - 9s/epoch - 114ms/step
# Epoch 7/10
#
# Epoch 7: accuracy improved from 0.94171 to 0.94828, saving model to vgg16_weights_with_freeze.best.hdf5
# 77/77 - 9s - loss: 0.1324 - accuracy: 0.9483 - 9s/epoch - 111ms/step
# Epoch 8/10
#
# Epoch 8: accuracy improved from 0.94828 to 0.95567, saving model to vgg16_weights_with_freeze.best.hdf5
# 77/77 - 8s - loss: 0.1461 - accuracy: 0.9557 - 8s/epoch - 102ms/step
# Epoch 9/10
#
# Epoch 9: accuracy did not improve from 0.95567
# 77/77 - 8s - loss: 0.1237 - accuracy: 0.9524 - 8s/epoch - 99ms/step
# Epoch 10/10
#
# Epoch 10: accuracy improved from 0.95567 to 0.96059, saving model to vgg16_weights_with_freeze.best.hdf5
# 77/77 - 8s - loss: 0.1144 - accuracy: 0.9606 - 8s/epoch - 99ms/step

# %%
show_history_plot(history)

# %%
predicts = predict(model, test_gen, weights_path)
show_confusion_matrix(train_gen, test_gen, predicts)
# Out:
# 19/19 [==============================] - 3s 186ms/step
# Accaccuracy score:  89.73509933774835

# %%
show_misclassified()
# Out:
#                            fname  true_label predicted_label
# 2       ceownik_00002-view02.png     ceownik      dwuteownik
# 3       ceownik_00003-view02.png     ceownik      dwuteownik
# 42      ceownik_00055-view01.png     ceownik      plaskownik
# 61   dwuteownik_00001-view03.png  dwuteownik         ceownik
# 78   dwuteownik_00023-view01.png  dwuteownik         ceownik
# 81   dwuteownik_00027-view04.png  dwuteownik         ceownik
# 96   dwuteownik_00046-view01.png  dwuteownik      plaskownik
# 111  dwuteownik_00069-view02.png  dwuteownik         ceownik
# 123  dwuteownik_00084-view03.png  dwuteownik         ceownik
# 133    katownik_00015-view03.png    katownik         ceownik
# 140    katownik_00023-view02.png    katownik      plaskownik
# 141    katownik_00023-view03.png    katownik      dwuteownik
# 142    katownik_00023-view04.png    katownik      plaskownik
# 143  plaskownik_00001-view02.png  plaskownik      dwuteownik
# 144  plaskownik_00001-view04.png  plaskownik      dwuteownik
# 157  plaskownik_00016-view02.png  plaskownik      dwuteownik
# 169  plaskownik_00036-view03.png  plaskownik         ceownik
# 179  plaskownik_00049-view02.png  plaskownik         ceownik
# 185  plaskownik_00056-view01.png  plaskownik         ceownik
# 186  plaskownik_00056-view03.png  plaskownik         ceownik
# 192  plaskownik_00066-view04.png  plaskownik         ceownik
# 213  plaskownik_00089-view04.png  plaskownik         ceownik
# 219  plaskownik_00096-view01.png  plaskownik      dwuteownik
# 222  plaskownik_00100-view01.png  plaskownik      dwuteownik
# 225  plaskownik_00103-view04.png  plaskownik      dwuteownik
# 247  plaskownik_00128-view02.png  plaskownik         ceownik
# 292  plaskownik_00182-view02.png  plaskownik      dwuteownik
# 293  plaskownik_00182-view04.png  plaskownik        katownik
# 294  plaskownik_00188-view02.png  plaskownik        katownik
# 295  plaskownik_00189-view03.png  plaskownik        katownik
# 300  plaskownik_00199-view02.png  plaskownik      dwuteownik

# %% [markdown]
# ## VGG16 - transfer wiedzy - bez zamrożenia

# %%
train_gen, test_gen = preprocess_and_load_data(vgg16.preprocess_input)

pretrained_model = vgg16.VGG16(weights="imagenet", include_top=False, input_shape=(ROWS, COLS,3))
pretrained_model.trainable = True
model = prepare_model(pretrained_model)

weights_path = "vgg16_weights_without_freeze.best.hdf5"
history = fit_model(model, weights_path)
# Out:
# Found 1218 images belonging to 4 classes.
# Found 302 images belonging to 4 classes.
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 9, 9, 512)         14714688
#
#  flatten_7 (Flatten)         (None, 41472)             0
#
#  dense_14 (Dense)            (None, 128)               5308544
#
#  dense_15 (Dense)            (None, 4)                 516
#
# =================================================================
# Total params: 20,023,748
# Trainable params: 20,023,748
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
#
# Epoch 1: accuracy improved from -inf to 0.21593, saving model to vgg16_weights_without_freeze.best.hdf5
# 77/77 - 25s - loss: nan - accuracy: 0.2159 - 25s/epoch - 324ms/step
# Epoch 2/10
#
# Epoch 2: accuracy did not improve from 0.21593
# 77/77 - 23s - loss: nan - accuracy: 0.2028 - 23s/epoch - 295ms/step
# Epoch 3/10
#
# Epoch 3: accuracy did not improve from 0.21593
# 77/77 - 23s - loss: nan - accuracy: 0.2028 - 23s/epoch - 295ms/step
# Epoch 4/10
#
# Epoch 4: accuracy did not improve from 0.21593
# 77/77 - 21s - loss: nan - accuracy: 0.2028 - 21s/epoch - 279ms/step
# Epoch 5/10
#
# Epoch 5: accuracy did not improve from 0.21593
# 77/77 - 24s - loss: nan - accuracy: 0.2028 - 24s/epoch - 310ms/step
# Epoch 6/10
#
# Epoch 6: accuracy did not improve from 0.21593
# 77/77 - 24s - loss: nan - accuracy: 0.2028 - 24s/epoch - 309ms/step
# Epoch 7/10
#
# Epoch 7: accuracy did not improve from 0.21593
# 77/77 - 21s - loss: nan - accuracy: 0.2028 - 21s/epoch - 267ms/step
# Epoch 8/10
#
# Epoch 8: accuracy did not improve from 0.21593
# 77/77 - 25s - loss: nan - accuracy: 0.2028 - 25s/epoch - 327ms/step
# Epoch 9/10
#
# Epoch 9: accuracy did not improve from 0.21593
# 77/77 - 23s - loss: nan - accuracy: 0.2028 - 23s/epoch - 296ms/step
# Epoch 10/10
#
# Epoch 10: accuracy did not improve from 0.21593
# 77/77 - 21s - loss: nan - accuracy: 0.2028 - 21s/epoch - 268ms/step

# %%
show_history_plot(history)

# %%
predicts = predict(model, test_gen, weights_path)
show_confusion_matrix(train_gen, test_gen, predicts)
# Out:
# 19/19 [==============================] - 2s 103ms/step
# Accaccuracy score:  20.198675496688743

# %%
show_misclassified()
# Out:
#                            fname  true_label predicted_label
# 61   dwuteownik_00001-view03.png  dwuteownik         ceownik
# 62   dwuteownik_00002-view01.png  dwuteownik         ceownik
# 63   dwuteownik_00002-view02.png  dwuteownik         ceownik
# 64   dwuteownik_00003-view02.png  dwuteownik         ceownik
# 65   dwuteownik_00005-view01.png  dwuteownik         ceownik
# ..                           ...         ...             ...
# 297  plaskownik_00193-view03.png  plaskownik         ceownik
# 298  plaskownik_00194-view01.png  plaskownik         ceownik
# 299  plaskownik_00197-view04.png  plaskownik         ceownik
# 300  plaskownik_00199-view02.png  plaskownik         ceownik
# 301  plaskownik_00199-view03.png  plaskownik         ceownik
#
# [241 rows x 3 columns]

# %% [markdown]
# ## VGG16 - bez transferu wiedzy

# %%
train_gen, test_gen = preprocess_and_load_data(vgg16.preprocess_input)

pretrained_model = vgg16.VGG16(weights=None, include_top=False, input_shape=(ROWS, COLS,3))
pretrained_model.trainable = True
model = prepare_model(pretrained_model)

weights_path = "vgg16_weights.best.hdf5"
history = fit_model(model, weights_path)
# Out:
# Found 1218 images belonging to 4 classes.
# Found 302 images belonging to 4 classes.
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 9, 9, 512)         14714688
#
#  flatten_8 (Flatten)         (None, 41472)             0
#
#  dense_16 (Dense)            (None, 128)               5308544
#
#  dense_17 (Dense)            (None, 4)                 516
#
# =================================================================
# Total params: 20,023,748
# Trainable params: 20,023,748
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
#
# Epoch 1: accuracy improved from -inf to 0.50575, saving model to vgg16_weights.best.hdf5
# 77/77 - 22s - loss: 1.2095 - accuracy: 0.5057 - 22s/epoch - 291ms/step
# Epoch 2/10
#
# Epoch 2: accuracy improved from 0.50575 to 0.51149, saving model to vgg16_weights.best.hdf5
# 77/77 - 21s - loss: 1.1868 - accuracy: 0.5115 - 21s/epoch - 275ms/step
# Epoch 3/10
#
# Epoch 3: accuracy improved from 0.51149 to 0.52299, saving model to vgg16_weights.best.hdf5
# 77/77 - 22s - loss: 1.1760 - accuracy: 0.5230 - 22s/epoch - 283ms/step
# Epoch 4/10
#
# Epoch 4: accuracy did not improve from 0.52299
# 77/77 - 20s - loss: 1.1950 - accuracy: 0.5230 - 20s/epoch - 260ms/step
# Epoch 5/10
#
# Epoch 5: accuracy did not improve from 0.52299
# 77/77 - 20s - loss: 1.1785 - accuracy: 0.5230 - 20s/epoch - 257ms/step
# Epoch 6/10
#
# Epoch 6: accuracy did not improve from 0.52299
# 77/77 - 20s - loss: 1.1627 - accuracy: 0.5230 - 20s/epoch - 263ms/step
# Epoch 7/10
#
# Epoch 7: accuracy improved from 0.52299 to 0.52381, saving model to vgg16_weights.best.hdf5
# 77/77 - 21s - loss: 1.1354 - accuracy: 0.5238 - 21s/epoch - 266ms/step
# Epoch 8/10
#
# Epoch 8: accuracy improved from 0.52381 to 0.55665, saving model to vgg16_weights.best.hdf5
# 77/77 - 20s - loss: 1.1060 - accuracy: 0.5567 - 20s/epoch - 266ms/step
# Epoch 9/10
#
# Epoch 9: accuracy improved from 0.55665 to 0.58949, saving model to vgg16_weights.best.hdf5
# 77/77 - 20s - loss: 1.0858 - accuracy: 0.5895 - 20s/epoch - 258ms/step
# Epoch 10/10
#
# Epoch 10: accuracy improved from 0.58949 to 0.59852, saving model to vgg16_weights.best.hdf5
# 77/77 - 20s - loss: 1.0265 - accuracy: 0.5985 - 20s/epoch - 259ms/step

# %%
show_history_plot(history)

# %%
predicts = predict(model, test_gen, weights_path)
show_confusion_matrix(train_gen, test_gen, predicts)
# Out:
# 19/19 [==============================] - 2s 98ms/step
# Accaccuracy score:  60.9271523178808

# %%
show_misclassified()
# Out:
#                          fname true_label predicted_label
# 0     ceownik_00001-view01.png    ceownik      plaskownik
# 1     ceownik_00001-view03.png    ceownik      plaskownik
# 2     ceownik_00002-view02.png    ceownik      plaskownik
# 3     ceownik_00003-view02.png    ceownik      plaskownik
# 4     ceownik_00006-view02.png    ceownik      plaskownik
# ..                         ...        ...             ...
# 138  katownik_00020-view02.png   katownik      plaskownik
# 139  katownik_00022-view03.png   katownik      plaskownik
# 140  katownik_00023-view02.png   katownik      plaskownik
# 141  katownik_00023-view03.png   katownik      plaskownik
# 142  katownik_00023-view04.png   katownik      plaskownik
#
# [118 rows x 3 columns]

# %% [markdown]
# ## Podsumowanie

# %%
sns.set(font_scale = 1.3)

train_acc = [76.19, 96.14, 52.30, 97.54, 99.26, 99.67, 96.06, 20.28, 59.85]
test_acc = [72.85, 93.38, 52.65, 93.71, 94.70, 52.65, 89.74, 20.20, 60.93]
labels = ['ResNet50TF','ResNet50T','ResNet50', 'XceptionTF', 'XceptionT', 'Xception', 'VGG16TF', 'VGG16T', 'VGG16']

x = np.arange(len(labels))
width = 0.4

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, train_acc, width, label='Train data')
rects2 = ax.bar(x + width/2, test_acc, width, label='Test data')

ax.set_ylabel('Accuracy')
ax.set_title('Accuracy by architecture and transfer learning')
plt.xticks(range(len(labels)), labels, size='small')
ax.legend()

ax.bar_label(rects1, padding=1)
ax.bar_label(rects2, padding=1)

fig.tight_layout()
fig.set_size_inches(15, 10)

plt.show()

# %% [markdown]
# Rozpoczynanie nauki z wagami pozyskanymi ze zbioru ImageNet poprawiało początkowe rezultaty i ułatwia uczenie sieci neuronowej.
# Po uczeniu trawjącym 10 epok, modele który miały odblokowaną możliwość aktualizacji zaimportowanych wag uzyskiwały wyższą trafność.
#
# Najlepsze wyniki otrzymano na architektórze Xception.
